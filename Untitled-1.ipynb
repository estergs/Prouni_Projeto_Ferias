# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df10 = pd.read_csv ('pda-prouni-2010.csv',sep=';', encoding='ISO-8859-1')
df11 = pd.read_csv ('pda-prouni-2011.csv',sep=';', encoding='ISO-8859-1')
df12 = pd.read_csv ('pda-prouni-2012.csv',sep=';', encoding='ISO-8859-1')
df13 = pd.read_csv ('pda-prouni-2013.csv',sep=';', encoding='ISO-8859-1')
df14 = pd.read_csv ('pda-prouni-2014.csv',sep=';', encoding='ISO-8859-1')
df15 = pd.read_csv ('pda-prouni-2015.csv',sep=';', encoding='ISO-8859-1')
df16 = pd.read_csv ('pda-prouni-2016.csv',sep=';', encoding='ISO-8859-1')
df17 = pd.read_csv ('pda-prouni-2017.csv',sep=';', encoding='UTF-8') # esse é diferente
df18 = pd.read_csv ('pda-prouni-2018.csv',sep=';', encoding='UTF-8')
df19 = pd.read_csv ('pda-prouni-2019.csv',sep=';', encoding='UTF-8')
df20 = pd.read_csv ('pda-prouni-2020.csv',sep=';', encoding='ISO-8859-1')

# %%
lista_dfs = [df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20]

df= pd.concat(lista_dfs, ignore_index=True)
df['ANO_CONCESSAO_BOLSA'] = df['ANO_CONCESSAO_BOLSA'].astype('Int64')

# %%
#Tratando a base os nomes das colunas estão divergentes

df['Sexo'] = df['SEXO_BENEFICIARIO'].combine_first(df['SEXO_BENEFICIARIO_BOLSA'])
df['Raca'] = df['RACA_BENEFICIARIO'].combine_first(df['RACA_BENEFICIARIO_BOLSA'])
df['UF'] = df['UF_BENEFICIARIO'].combine_first(df['SIGLA_UF_BENEFICIARIO_BOLSA'])
df['Municipio'] = df['MUNICIPIO_BENEFICIARIO'].combine_first(df['MUNICIPIO_BENEFICIARIO_BOLSA'])
df['Municipio'] = df['Municipio'].combine_first(df['MUNICIPIO'])
df['Regiao'] = df['REGIAO_BENEFICIARIO'].combine_first(df['REGIAO_BENEFICIARIO_BOLSA'])

# Eliminando as colunas duplicadas antigas e obsoletas
df.drop(columns=[
    'CPF_BENEFICIARIO', 'CPF_BENEFICIARIO_BOLSA',
    'DATA_NASCIMENTO', 'DT_NASCIMENTO_BENEFICIARIO',
    'SEXO_BENEFICIARIO', 'SEXO_BENEFICIARIO_BOLSA',
    'RACA_BENEFICIARIO', 'RACA_BENEFICIARIO_BOLSA',
    'UF_BENEFICIARIO', 'SIGLA_UF_BENEFICIARIO_BOLSA',
    'MUNICIPIO', 'MUNICIPIO_BENEFICIARIO','MUNICIPIO_BENEFICIARIO_BOLSA',
    'REGIAO_BENEFICIARIO', 'REGIAO_BENEFICIARIO_BOLSA'
], inplace=True)


print(df.columns)
# Out:
# Index(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
#        'NOME_TURNO_CURSO_BOLSA', 'BENEFICIARIO_DEFICIENTE_FISICO', 'CAMPUS',
#        'Sexo', 'Raca', 'UF', 'Municipio', 'Regiao'],
#       dtype='object')

# %%
df = df.rename(columns={
    # Padronização de ano
    'ANO_CONCESSAO_BOLSA': 'Ano',

    # IES
    'CODIGO_EMEC_IES_BOLSA': 'Codigo_IES',
    'NOME_IES_BOLSA': 'Nome_IES',
    
    # Curso
    'CAMPUS': 'Campus',
    'TIPO_BOLSA': 'Tipo_Bolsa',
    'MODALIDADE_ENSINO_BOLSA': 'Modalidade',
    'NOME_CURSO_BOLSA': 'Curso',
    'NOME_TURNO_CURSO_BOLSA': 'Turno',

    # Beneficiário
    'BENEFICIARIO_DEFICIENTE_FISICO': 'Deficiencia'
})
print(df.columns)
# Out:
# Index(['Ano', 'Codigo_IES', 'Nome_IES', 'Tipo_Bolsa', 'Modalidade', 'Curso',
#        'Turno', 'Deficiencia', 'Campus', 'Sexo', 'Raca', 'UF', 'Municipio',
#        'Regiao'],
#       dtype='object')

# %%
#Criei uma coluna auxiliar pra me ajudar a fazer os agrupamentos
df['Cont'] = 1

# %%
# Padronizando o texto
df['Curso'] = df['Curso'].str.title().str.strip()
df
# Out:
#           Ano  Codigo_IES                                           Nome_IES  \
# 0        2010        20.0                        UNIVERSIDADE DE PASSO FUNDO
# 1        2010        20.0                        UNIVERSIDADE DE PASSO FUNDO
# 2        2010        20.0                        UNIVERSIDADE DE PASSO FUNDO
# 3        2010        20.0                        UNIVERSIDADE DE PASSO FUNDO
# 4        2010       423.0  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...
# ...       ...         ...                                                ...
# 2278624  2020      1491.0                 CENTRO UNIVERSITÁRIO INTERNACIONAL
# 2278625  2020      1491.0                 CENTRO UNIVERSITÁRIO INTERNACIONAL
# 2278626  2020      1491.0                 CENTRO UNIVERSITÁRIO INTERNACIONAL
# 2278627  2020      1491.0                 CENTRO UNIVERSITÁRIO INTERNACIONAL
# 2278628  2020      1491.0                 CENTRO UNIVERSITÁRIO INTERNACIONAL
#
#                 Tipo_Bolsa  Modalidade                    Curso  \
# 0        BOLSA PARCIAL 50%  PRESENCIAL            Administração
# 1        BOLSA PARCIAL 50%  PRESENCIAL            Administração
# 2        BOLSA PARCIAL 50%  PRESENCIAL            Administração
# 3           BOLSA INTEGRAL  PRESENCIAL            Administração
# 4           BOLSA INTEGRAL  PRESENCIAL                  Direito
# ...                    ...         ...                      ...
# 2278624            PARCIAL         EAD            Administração
# 2278625            PARCIAL         EAD  Relações Internacionais
# 2278626            PARCIAL         EAD            Administração
# 2278627            PARCIAL         EAD  Relações Internacionais
# 2278628            PARCIAL         EAD                   Música
#
#                      Turno Deficiencia          Campus       Sexo    Raca  UF  \
# 0                  Noturno         NÃO             NaN  Masculino  Branca  RS
# 1                  Noturno         NÃO             NaN   Feminino  Branca  RS
# 2                  Noturno         NÃO             NaN  Masculino  Branca  RS
# 3                  Noturno         NÃO             NaN  Masculino  Branca  RS
# 4                  Noturno         NÃO             NaN   Feminino  Branca  RS
# ...                    ...         ...             ...        ...     ...  ..
# 2278624  CURSO A DISTÂNCIA           N   PAP CABO FRIO          F   Parda  RJ
# 2278625  CURSO A DISTÂNCIA           N   PAP CABO FRIO          F   Parda  RJ
# 2278626  CURSO A DISTÂNCIA           N      PAP CANOAS          M  Branca  RS
# 2278627  CURSO A DISTÂNCIA           N  PAP ANANINDEUA          F   Parda  PA
# 2278628  CURSO A DISTÂNCIA           N     PAP LAJEADO          M  Branca  RS
#
#                     Municipio   Regiao  Cont
# 0        PALMEIRA DAS MISSÕES      SUL     1
# 1        PALMEIRA DAS MISSÕES      SUL     1
# 2        PALMEIRA DAS MISSÕES      SUL     1
# 3        PALMEIRA DAS MISSÕES      SUL     1
# 4                     ERECHIM      SUL     1
# ...                       ...      ...   ...
# 2278624   SAO PEDRO DA ALDEIA  SUDESTE     1
# 2278625              ARARUAMA  SUDESTE     1
# 2278626                CANOAS      SUL     1
# 2278627            ANANINDEUA    NORTE     1
# 2278628               ESTRELA      SUL     1
#
# [2278629 rows x 15 columns]

# %%
# Evolução do numero de bolsa
df_bolsa = df.groupby('Ano')['Cont'].sum().reset_index()
df_bolsa
# Out:
#      Ano    Cont
# 0   2010  152733
# 1   2011  170766
# 2   2012  176764
# 3   2013  177326
# 4   2014  223598
# 5   2015  252650
# 6   2016  239262
# 7   2017  236636
# 8   2018  241032
# 9   2019  225555
# 10  2020  166830

# %%
df['Tipo_Bolsa'] = df['Tipo_Bolsa'].replace({
    'BOLSA INTEGRAL': 'INTEGRAL',
    'INTEGRAL': 'INTEGRAL',
    'BOLSA PARCIAL 50%': 'PARCIAL',
    'PARCIAL': 'PARCIAL'
})
# Distribuição por tipo de bolsa
df_tipo_bolsa= df.groupby('Tipo_Bolsa')['Cont'].sum().reset_index()
df_tipo_bolsa
# Out:
#   Tipo_Bolsa     Cont
# 0   INTEGRAL  1590182
# 1    PARCIAL   672970

# %%
# Cursos Mais procurados 
df_curso = df.groupby('Curso')['Cont'].sum().reset_index()
df_curso = df_curso.sort_values(by='Cont', ascending=False)
df_curso
# Out:
#                                                   Curso    Cont
# 10                                        Administração  247002
# 1301                                            Direito  183242
# 2102                                          Pedagogia  165704
# 248                                  Ciências Contábeis  120480
# 1419                                         Enfermagem   86192
# ...                                                 ...     ...
# 2348                           Tecnologia Da Informação       1
# 712   Curso Superior De Tecnologia Em Gestão Comerci...       1
# 1608                   Engenharia Elétrica - Alphaville       1
# 420   Curso Superior De Tecnologia  Em Comércio Exte...       1
# 2371  Tecnologia Em Gestão De Comércio Exterior A Di...       1
#
# [2434 rows x 2 columns]

# %%
# Distribuiçnao por municipio 
df_muni = df.groupby('Municipio')['Cont'].sum().reset_index()
df_muni = df_muni.sort_values(by='Cont', ascending=False)
df_muni
# Out:
#                             Municipio    Cont
# 6850                        SÃO PAULO  110151
# 6299                        SAO PAULO   64638
# 773                    BELO HORIZONTE   53887
# 5551                   RIO DE JANEIRO   52791
# 1965                         CURITIBA   44313
# ...                               ...     ...
# 4295              MURICI DOS PORTELAS       1
# 6643  SÃO FRANCISCO DE ASSIS DO PIAUÍ       1
# 3495                        JOÃO DIAS       1
# 6632           SÃO DOMINGOS DO CARIRI       1
# 6838            SÃO MIGUEL DO FIDALGO       1
#
# [7579 rows x 2 columns]

# %%
plt.plot(df_bolsa['Ano'],df_bolsa['Cont'])
plt.title('\nEvolução Concessão de bolsa\n')
plt.xlabel('\nAno\n')
plt.ylabel('\nConcessão de bolsa\n')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
